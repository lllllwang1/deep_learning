# %% [markdown]
# # Advanced Image Classification with ImageNet

# %% [markdown]
# In this assignment, you will be asked to develop a convolutional neural network (CNN) to classify images from the CIFAR-100 dataset. At each step, you'll be guided through the process of developing a model architecture to solve a problem. Your goal is to create a CNN that attains at least 55% accuracy on the validation set.
#
# ### The CIFAR-100 Dataset
#
# The [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html) consists of 60000 32x32 colour images in 100 classes, with 600 images per class. There are 50000 training images and 10000 test images. The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 500 images from each class.
#
# ### Tools
#
# You will use Keras with TensorFlow to develop your CNN. For this assignment, it's strongly recommended that you use a GPU to accelerate your training, or else you might find it difficult to train your network in a reasonable amount of time. If you have a computer with a GPU that you wish to use, you can follow the [TensorFlow instructions](https://www.tensorflow.org/install/) for installing TensorFlow with GPU support. Otherwise, you can use [Google Colab](https://colab.research.google.com/) to complete this assignment. Colab provides free access to GPU-enabled machines. If you run into any issues, please contact us as soon as possible so that we can help you resolve them.

# %% [markdown]
# ## Task 1: Data Exploration and Preprocessing (Complete or Incomplete)
# ### 1a: Load and Explore the Dataset
# - Use the code below to download the dataset.
# - Explore the dataset: examine the shape of the training and test sets, the dimensions of the images, and the number of classes. Show a few examples from the training set.

# %%
from keras.datasets import cifar100
import matplotlib.pyplot as plt

# Load the CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt

print("Training set shape:", x_train.shape)
print("Test set shape:", x_test.shape)
print("Training labels shape:", y_train.shape)
print("Test labels shape:", y_test.shape)

image_shape = x_train[0].shape
print("Image dimensions:", image_shape)

# Get the number of classes
num_classes = len(set(y_train.flatten()))
print("Number of classes:", num_classes)

# Visualize a few examples from the training set
num_examples = 10
plt.figure(figsize=(10, 2))
for i in range(num_examples):
    plt.subplot(1, num_examples, i + 1)
    plt.imshow(x_train[i])
    plt.axis('off')
plt.show()
# Out:
# Training set shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test labels shape: (10000, 1)
# Image dimensions: (32, 32, 3)
# Number of classes: 100

# %% [markdown]
# ### 1b: Data Preprocessing (4 Marks)
# - With the data downloaded, it's time to preprocess it. Start by normalizing the images so that they all have pixel values in the range [0, 1].
# - Next, convert the labels to one-hot encoded vectors.
# - Finally, split the training set into training and validation sets. Use 80% of the training set for training and the remaining 20% for validation.

# %%
# Your code here
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Normalize the images to have pixel values in the range [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

# Split the training set into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Task 2: Model Development (Complete or Incomplete)
# ### Task 2a: Create a Baseline CNN Model
# - Design a CNN architecture. Your architecture should use convolutional layers, max pooling layers, and dense layers. You can use any number of layers, and you can experiment with different numbers of filters, filter sizes, strides, padding, etc. The design doesn't need to be perfect, but it should be unique to you.
# - Print out the model summary.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Your code here
# Initialize the model
model = Sequential()

# Add the first convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))

# Add the second convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Flatten the output from the convolutional layers
model.add(Flatten())

# Add a fully connected layer
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

# Add the output layer
model.add(Dense(100, activation='softmax'))  

# Print out the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 256)               590080
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 635172 (2.42 MB)
# Trainable params: 635172 (2.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Task 2b: Compile the model
#
# - Select an appropriate loss function and optimizer for your model. These can be ones we have looked at already, or they can be different.
# - Briefly explain your choices (one or two sentences each).
# - <b>Loss function:</b> Categorial_crossentropy
# - <b>Optimizer:</b> SGD

# %%
# Your code here
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD

model.compile(
    loss='categorical_crossentropy', # Loss function
    optimizer=optimizers.SGD(learning_rate=0.1), # Optimizer
    metrics=['accuracy'] # Metrics to evaluate the model
)

loss, accuracy = model.evaluate(x_test, y_test)

print(f'Loss:     {loss:.2f}')
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# 313/313 [==============================] - 1s 3ms/step - loss: 4.6077 - accuracy: 0.0123
# Loss:     4.61
# Accuracy: 1.23%

# %% [markdown]
# ## Task 3: Model Training and Evaluation (Complete or Incomplete)
# ### Task 3a: Train the Model
#
# - Train your model for an appropriate number of epochs. Explain your choice of the number of epochs used - you can change this number before submitting your assignment.
# - Use a batch size of 32.
# - Use the validation set for validation.

# %%
# Your code here
history = model.fit(
    x_train,                # Training data
    y_train,        # Training labels (one-hot encoded)
    epochs=75,              # Number of epochs to train
    batch_size=32,          # Batch size
    validation_data=(x_val, y_val),  # Validation data
)
# Out:
# Epoch 1/75
# 1250/1250 [==============================] - 12s 9ms/step - loss: 4.2895 - accuracy: 0.0506 - val_loss: 3.8229 - val_accuracy: 0.1173
# Epoch 2/75
# 1250/1250 [==============================] - 11s 8ms/step - loss: 3.7712 - accuracy: 0.1248 - val_loss: 3.4201 - val_accuracy: 0.1850
# Epoch 3/75
# 1250/1250 [==============================] - 11s 8ms/step - loss: 3.4663 - accuracy: 0.1730 - val_loss: 3.1315 - val_accuracy: 0.2391
# Epoch 4/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 3.2534 - accuracy: 0.2152 - val_loss: 3.0089 - val_accuracy: 0.2586
# Epoch 5/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 3.0846 - accuracy: 0.2459 - val_loss: 2.8801 - val_accuracy: 0.2913
# Epoch 6/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.9434 - accuracy: 0.2717 - val_loss: 2.8266 - val_accuracy: 0.3053
# Epoch 7/75
# 1250/1250 [==============================] - 11s 8ms/step - loss: 2.8196 - accuracy: 0.2939 - val_loss: 2.7667 - val_accuracy: 0.3123
# Epoch 8/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.7219 - accuracy: 0.3133 - val_loss: 2.7347 - val_accuracy: 0.3292
# Epoch 9/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.6114 - accuracy: 0.3348 - val_loss: 2.7647 - val_accuracy: 0.3161
# Epoch 10/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.5260 - accuracy: 0.3518 - val_loss: 2.6850 - val_accuracy: 0.3369
# Epoch 11/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.4294 - accuracy: 0.3743 - val_loss: 2.6474 - val_accuracy: 0.3529
# Epoch 12/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.3511 - accuracy: 0.3846 - val_loss: 2.6505 - val_accuracy: 0.3498
# Epoch 13/75
# 1250/1250 [==============================] - 11s 9ms/step - loss: 2.2765 - accuracy: 0.3993 - val_loss: 2.7401 - val_accuracy: 0.3292
# Epoch 14/75
# 1250/1250 [==============================] - 12s 10ms/step - loss: 2.1951 - accuracy: 0.4159 - val_loss: 2.6977 - val_accuracy: 0.3483
# Epoch 15/75
# 1250/1250 [==============================] - 13s 10ms/step - loss: 2.1285 - accuracy: 0.4303 - val_loss: 2.8131 - val_accuracy: 0.3380
# Epoch 16/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.0606 - accuracy: 0.4453 - val_loss: 2.7462 - val_accuracy: 0.3409
# Epoch 17/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.9985 - accuracy: 0.4570 - val_loss: 2.8246 - val_accuracy: 0.3375
# Epoch 18/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 1.9557 - accuracy: 0.4656 - val_loss: 2.8858 - val_accuracy: 0.3258
# Epoch 19/75
# 1250/1250 [==============================] - 16s 12ms/step - loss: 1.9015 - accuracy: 0.4781 - val_loss: 2.8725 - val_accuracy: 0.3344
# Epoch 20/75
# 1250/1250 [==============================] - 14s 12ms/step - loss: 1.8515 - accuracy: 0.4892 - val_loss: 2.9172 - val_accuracy: 0.3189
# Epoch 21/75
# 1250/1250 [==============================] - 14s 12ms/step - loss: 1.8107 - accuracy: 0.4962 - val_loss: 2.9471 - val_accuracy: 0.3246
# Epoch 22/75
# 1250/1250 [==============================] - 14s 11ms/step - loss: 1.7581 - accuracy: 0.5092 - val_loss: 3.0192 - val_accuracy: 0.3241
# Epoch 23/75
# 1250/1250 [==============================] - 16s 13ms/step - loss: 1.7199 - accuracy: 0.5210 - val_loss: 2.9933 - val_accuracy: 0.3277
# Epoch 24/75
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.7085 - accuracy: 0.5222 - val_loss: 3.1209 - val_accuracy: 0.3231
# Epoch 25/75
# 1250/1250 [==============================] - 30s 24ms/step - loss: 1.6752 - accuracy: 0.5283 - val_loss: 3.0849 - val_accuracy: 0.3263
# Epoch 26/75
# 1250/1250 [==============================] - 23s 18ms/step - loss: 1.6428 - accuracy: 0.5364 - val_loss: 3.2063 - val_accuracy: 0.3219
# Epoch 27/75
# 1250/1250 [==============================] - 22s 17ms/step - loss: 1.6151 - accuracy: 0.5437 - val_loss: 3.2181 - val_accuracy: 0.3151
# Epoch 28/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.5946 - accuracy: 0.5504 - val_loss: 3.2481 - val_accuracy: 0.3177
# Epoch 29/75
# 1250/1250 [==============================] - 21s 16ms/step - loss: 1.5628 - accuracy: 0.5591 - val_loss: 3.3259 - val_accuracy: 0.3145
# Epoch 30/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.5438 - accuracy: 0.5622 - val_loss: 3.3632 - val_accuracy: 0.3125
# Epoch 31/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.5224 - accuracy: 0.5688 - val_loss: 3.4049 - val_accuracy: 0.3152
# Epoch 32/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.4902 - accuracy: 0.5765 - val_loss: 3.4242 - val_accuracy: 0.3166
# Epoch 33/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.4995 - accuracy: 0.5724 - val_loss: 3.3694 - val_accuracy: 0.3069
# Epoch 34/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.4680 - accuracy: 0.5803 - val_loss: 3.4734 - val_accuracy: 0.3118
# Epoch 35/75
# 1250/1250 [==============================] - 19s 16ms/step - loss: 1.4472 - accuracy: 0.5869 - val_loss: 3.6546 - val_accuracy: 0.3133
# Epoch 36/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.4411 - accuracy: 0.5867 - val_loss: 3.6615 - val_accuracy: 0.3101
# Epoch 37/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.4316 - accuracy: 0.5936 - val_loss: 3.7396 - val_accuracy: 0.3134
# Epoch 38/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.4227 - accuracy: 0.5941 - val_loss: 3.7150 - val_accuracy: 0.3087
# Epoch 39/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3921 - accuracy: 0.6019 - val_loss: 3.7871 - val_accuracy: 0.3101
# Epoch 40/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3735 - accuracy: 0.6063 - val_loss: 3.7331 - val_accuracy: 0.2978
# Epoch 41/75
# 1250/1250 [==============================] - 22s 17ms/step - loss: 1.4038 - accuracy: 0.5997 - val_loss: 3.8406 - val_accuracy: 0.2992
# Epoch 42/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.3884 - accuracy: 0.6037 - val_loss: 3.9423 - val_accuracy: 0.3090
# Epoch 43/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.3568 - accuracy: 0.6148 - val_loss: 4.0252 - val_accuracy: 0.3004
# Epoch 44/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.3561 - accuracy: 0.6118 - val_loss: 3.9552 - val_accuracy: 0.3019
# Epoch 45/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.3658 - accuracy: 0.6122 - val_loss: 4.1296 - val_accuracy: 0.3049
# Epoch 46/75
# 1250/1250 [==============================] - 21s 16ms/step - loss: 1.3575 - accuracy: 0.6162 - val_loss: 3.9948 - val_accuracy: 0.2934
# Epoch 47/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3524 - accuracy: 0.6126 - val_loss: 4.1428 - val_accuracy: 0.2936
# Epoch 48/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3236 - accuracy: 0.6213 - val_loss: 4.2234 - val_accuracy: 0.3013
# Epoch 49/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3329 - accuracy: 0.6201 - val_loss: 4.1503 - val_accuracy: 0.3033
# Epoch 50/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.3491 - accuracy: 0.6184 - val_loss: 4.0899 - val_accuracy: 0.2894
# Epoch 51/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.3106 - accuracy: 0.6274 - val_loss: 4.3093 - val_accuracy: 0.2941
# Epoch 52/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.3564 - accuracy: 0.6159 - val_loss: 4.4061 - val_accuracy: 0.2975
# Epoch 53/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.3209 - accuracy: 0.6273 - val_loss: 4.4350 - val_accuracy: 0.2889
# Epoch 54/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3268 - accuracy: 0.6251 - val_loss: 4.2797 - val_accuracy: 0.2908
# Epoch 55/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3187 - accuracy: 0.6270 - val_loss: 4.2797 - val_accuracy: 0.2986
# Epoch 56/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3250 - accuracy: 0.6263 - val_loss: 4.4832 - val_accuracy: 0.2964
# Epoch 57/75
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.3490 - accuracy: 0.6203 - val_loss: 4.5957 - val_accuracy: 0.2789
# Epoch 58/75
# 1250/1250 [==============================] - 17s 14ms/step - loss: 1.3132 - accuracy: 0.6308 - val_loss: 4.4075 - val_accuracy: 0.2960
# Epoch 59/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3239 - accuracy: 0.6280 - val_loss: 4.6686 - val_accuracy: 0.2912
# Epoch 60/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3338 - accuracy: 0.6255 - val_loss: 4.4707 - val_accuracy: 0.2868
# Epoch 61/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.2943 - accuracy: 0.6351 - val_loss: 4.8209 - val_accuracy: 0.2941
# Epoch 62/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.2955 - accuracy: 0.6352 - val_loss: 4.5059 - val_accuracy: 0.2991
# Epoch 63/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.3029 - accuracy: 0.6342 - val_loss: 4.6165 - val_accuracy: 0.2855
# Epoch 64/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.2976 - accuracy: 0.6364 - val_loss: 4.5613 - val_accuracy: 0.2833
# Epoch 65/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.2968 - accuracy: 0.6363 - val_loss: 4.7362 - val_accuracy: 0.2883
# Epoch 66/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.3049 - accuracy: 0.6370 - val_loss: 4.6427 - val_accuracy: 0.2864
# Epoch 67/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.2864 - accuracy: 0.6398 - val_loss: 4.4809 - val_accuracy: 0.2854
# Epoch 68/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.3055 - accuracy: 0.6377 - val_loss: 4.8316 - val_accuracy: 0.2875
# Epoch 69/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.3170 - accuracy: 0.6345 - val_loss: 4.7788 - val_accuracy: 0.2814
# Epoch 70/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 1.2939 - accuracy: 0.6429 - val_loss: 4.7529 - val_accuracy: 0.2826
# Epoch 71/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.2934 - accuracy: 0.6421 - val_loss: 4.7972 - val_accuracy: 0.2782
# Epoch 72/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.2896 - accuracy: 0.6435 - val_loss: 4.6357 - val_accuracy: 0.2810
# Epoch 73/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 1.3052 - accuracy: 0.6375 - val_loss: 4.9289 - val_accuracy: 0.2829
# Epoch 74/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.2757 - accuracy: 0.6486 - val_loss: 5.1261 - val_accuracy: 0.2861
# Epoch 75/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 1.2923 - accuracy: 0.6393 - val_loss: 4.9765 - val_accuracy: 0.2869

# %% [markdown]
# ### Task 3b: Accuracy and other relevant metrics on the test set
#
# - Report the accuracy of your model on the test set.
# - While accuracy is a good metric, there are many other ways to numerically evaluate a model. Report at least one other metric, and explain what it measures and how it is calculated.
#
# - <b>Accuracy:</b> 68%
# - <b>Other metric:</b> F1 Score
# - <b>Reason for selection:</b>  The F1 score provides a balance between precision and recall, especially useful for imbalanced datasets
# - <b>Value of metric:</b> 0.2803
# - <b>Interpretation of metric value:</b> A higher F1 score indicates a better balance between precision and recall, suggesting good model performance.

# %%
# Your code here
from sklearn.metrics import f1_score

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy}")

# Predictions for the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Calculate F1 score
f1 = f1_score(y_true, y_pred_classes, average='weighted')
print(f"F1 Score: {f1}")

# Report the metrics
print(f"Accuracy: {test_accuracy}")
print(f"Value of metric: {f1:.4f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 4.9541 - accuracy: 0.2826
# Test Accuracy: 0.2825999855995178
# 313/313 [==============================] - 1s 3ms/step
# F1 Score: 0.28029825650125145
# Accuracy: 0.2825999855995178
# Value of metric: 0.2803

# %% [markdown]
# ### Task 3c: Visualize the model's learning
#
# - Plot the training accuracy and validation accuracy with respect to epochs.
# - Select an image that the model correctly classified in the test set, and an image that the model incorrectly classified in the test set. Plot the images and report the model's classification probabilities for each.
# - Briefly discuss the results. What do the plots show? Do the results make sense? What do the classification probabilities indicate?

# %%
# Your code here
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Task 4: Model Enhancement (Complete or Incomplete)
# ### Task 4a: Implementation of at least one advanced technique
#
# - Now it's time to improve your model. Implement at least one technique to improve your model's performance. You can use any of the techniques we have covered in class, or you can use a technique that we haven't covered. If you need inspiration, you can refer to the [Keras documentation](https://keras.io/).
# - Explain the technique you used and why you chose it.
# - If you used a technique that requires tuning, explain how you selected the values for the hyperparameters.

# %%
# Your code here
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)
datagen.fit(x_train)

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=75,
                    validation_data=(x_val, y_val),
                    callbacks=[lr_scheduler],
                    verbose=1)
# Out:
# Epoch 1/75
# 1250/1250 [==============================] - 17s 13ms/step - loss: 3.9390 - accuracy: 0.1553 - val_loss: 3.4569 - val_accuracy: 0.2147 - lr: 0.0010
# Epoch 2/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 3.1260 - accuracy: 0.2569 - val_loss: 3.1263 - val_accuracy: 0.2694 - lr: 0.0010
# Epoch 3/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.8812 - accuracy: 0.3020 - val_loss: 3.0089 - val_accuracy: 0.3023 - lr: 0.0010
# Epoch 4/75
# 1250/1250 [==============================] - 14s 11ms/step - loss: 2.7488 - accuracy: 0.3325 - val_loss: 2.7131 - val_accuracy: 0.3430 - lr: 0.0010
# Epoch 5/75
# 1250/1250 [==============================] - 14s 11ms/step - loss: 2.6291 - accuracy: 0.3548 - val_loss: 2.7330 - val_accuracy: 0.3526 - lr: 0.0010
# Epoch 6/75
# 1250/1250 [==============================] - 14s 12ms/step - loss: 2.5665 - accuracy: 0.3681 - val_loss: 2.9312 - val_accuracy: 0.3122 - lr: 0.0010
# Epoch 7/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.5016 - accuracy: 0.3844 - val_loss: 2.6109 - val_accuracy: 0.3739 - lr: 0.0010
# Epoch 8/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.4485 - accuracy: 0.3961 - val_loss: 2.5682 - val_accuracy: 0.3794 - lr: 0.0010
# Epoch 9/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.4073 - accuracy: 0.4039 - val_loss: 2.6294 - val_accuracy: 0.3744 - lr: 0.0010
# Epoch 10/75
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.3655 - accuracy: 0.4135 - val_loss: 2.6655 - val_accuracy: 0.3719 - lr: 0.0010
# Epoch 11/75
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.3367 - accuracy: 0.4237 - val_loss: 2.4852 - val_accuracy: 0.4016 - lr: 0.0010
# Epoch 12/75
# 1250/1250 [==============================] - 16s 13ms/step - loss: 2.2979 - accuracy: 0.4295 - val_loss: 3.0051 - val_accuracy: 0.3325 - lr: 0.0010
# Epoch 13/75
# 1250/1250 [==============================] - 15s 12ms/step - loss: 2.2820 - accuracy: 0.4349 - val_loss: 2.8108 - val_accuracy: 0.3541 - lr: 0.0010
# Epoch 14/75
# 1250/1250 [==============================] - 17s 13ms/step - loss: 2.2596 - accuracy: 0.4390 - val_loss: 2.8415 - val_accuracy: 0.3483 - lr: 0.0010
# Epoch 15/75
# 1250/1250 [==============================] - 17s 14ms/step - loss: 2.2373 - accuracy: 0.4428 - val_loss: 2.7671 - val_accuracy: 0.3612 - lr: 0.0010
# Epoch 16/75
# 1250/1250 [==============================] - 18s 14ms/step - loss: 2.2292 - accuracy: 0.4473 - val_loss: 2.3037 - val_accuracy: 0.4439 - lr: 0.0010
# Epoch 17/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 2.2004 - accuracy: 0.4526 - val_loss: 2.4690 - val_accuracy: 0.4205 - lr: 0.0010
# Epoch 18/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 2.1935 - accuracy: 0.4548 - val_loss: 2.4448 - val_accuracy: 0.4229 - lr: 0.0010
# Epoch 19/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 2.1756 - accuracy: 0.4589 - val_loss: 2.6191 - val_accuracy: 0.3993 - lr: 0.0010
# Epoch 20/75
# 1250/1250 [==============================] - 22s 18ms/step - loss: 2.1596 - accuracy: 0.4621 - val_loss: 2.4949 - val_accuracy: 0.4199 - lr: 0.0010
# Epoch 21/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 2.1506 - accuracy: 0.4644 - val_loss: 2.9285 - val_accuracy: 0.3451 - lr: 0.0010
# Epoch 22/75
# 1250/1250 [==============================] - 19s 15ms/step - loss: 2.0386 - accuracy: 0.4902 - val_loss: 2.3383 - val_accuracy: 0.4448 - lr: 5.0000e-04
# Epoch 23/75
# 1250/1250 [==============================] - 18s 15ms/step - loss: 2.0105 - accuracy: 0.4981 - val_loss: 3.1801 - val_accuracy: 0.3271 - lr: 5.0000e-04
# Epoch 24/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.9911 - accuracy: 0.4992 - val_loss: 2.6505 - val_accuracy: 0.3945 - lr: 5.0000e-04
# Epoch 25/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.9761 - accuracy: 0.5011 - val_loss: 2.3270 - val_accuracy: 0.4522 - lr: 5.0000e-04
# Epoch 26/75
# 1250/1250 [==============================] - 22s 18ms/step - loss: 1.9732 - accuracy: 0.5050 - val_loss: 2.2474 - val_accuracy: 0.4661 - lr: 5.0000e-04
# Epoch 27/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.9585 - accuracy: 0.5069 - val_loss: 2.2500 - val_accuracy: 0.4591 - lr: 5.0000e-04
# Epoch 28/75
# 1250/1250 [==============================] - 23s 18ms/step - loss: 1.9598 - accuracy: 0.5045 - val_loss: 2.3431 - val_accuracy: 0.4518 - lr: 5.0000e-04
# Epoch 29/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.9479 - accuracy: 0.5089 - val_loss: 2.3233 - val_accuracy: 0.4582 - lr: 5.0000e-04
# Epoch 30/75
# 1250/1250 [==============================] - 23s 18ms/step - loss: 1.9467 - accuracy: 0.5067 - val_loss: 2.2448 - val_accuracy: 0.4668 - lr: 5.0000e-04
# Epoch 31/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.9298 - accuracy: 0.5108 - val_loss: 2.3773 - val_accuracy: 0.4382 - lr: 5.0000e-04
# Epoch 32/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.9313 - accuracy: 0.5126 - val_loss: 2.4729 - val_accuracy: 0.4310 - lr: 5.0000e-04
# Epoch 33/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.9230 - accuracy: 0.5132 - val_loss: 2.3124 - val_accuracy: 0.4564 - lr: 5.0000e-04
# Epoch 34/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.9230 - accuracy: 0.5117 - val_loss: 2.4512 - val_accuracy: 0.4306 - lr: 5.0000e-04
# Epoch 35/75
# 1250/1250 [==============================] - 21s 17ms/step - loss: 1.9165 - accuracy: 0.5140 - val_loss: 2.3048 - val_accuracy: 0.4462 - lr: 5.0000e-04
# Epoch 36/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.8622 - accuracy: 0.5266 - val_loss: 2.1583 - val_accuracy: 0.4782 - lr: 2.5000e-04
# Epoch 37/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.8425 - accuracy: 0.5319 - val_loss: 2.2126 - val_accuracy: 0.4707 - lr: 2.5000e-04
# Epoch 38/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.8414 - accuracy: 0.5335 - val_loss: 2.1684 - val_accuracy: 0.4842 - lr: 2.5000e-04
# Epoch 39/75
# 1250/1250 [==============================] - 19s 16ms/step - loss: 1.8254 - accuracy: 0.5347 - val_loss: 2.2064 - val_accuracy: 0.4739 - lr: 2.5000e-04
# Epoch 40/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.8229 - accuracy: 0.5348 - val_loss: 2.3655 - val_accuracy: 0.4538 - lr: 2.5000e-04
# Epoch 41/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.8232 - accuracy: 0.5345 - val_loss: 2.4696 - val_accuracy: 0.4287 - lr: 2.5000e-04
# Epoch 42/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.7896 - accuracy: 0.5426 - val_loss: 2.3228 - val_accuracy: 0.4616 - lr: 1.2500e-04
# Epoch 43/75
# 1250/1250 [==============================] - 20s 16ms/step - loss: 1.7741 - accuracy: 0.5436 - val_loss: 2.1786 - val_accuracy: 0.4832 - lr: 1.2500e-04
# Epoch 44/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7790 - accuracy: 0.5446 - val_loss: 2.3190 - val_accuracy: 0.4550 - lr: 1.2500e-04
# Epoch 45/75
# 1250/1250 [==============================] - 26s 20ms/step - loss: 1.7660 - accuracy: 0.5448 - val_loss: 2.2855 - val_accuracy: 0.4605 - lr: 1.2500e-04
# Epoch 46/75
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.7716 - accuracy: 0.5460 - val_loss: 2.2378 - val_accuracy: 0.4707 - lr: 1.2500e-04
# Epoch 47/75
# 1250/1250 [==============================] - 27s 22ms/step - loss: 1.7471 - accuracy: 0.5496 - val_loss: 2.2680 - val_accuracy: 0.4665 - lr: 6.2500e-05
# Epoch 48/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.7504 - accuracy: 0.5511 - val_loss: 2.1830 - val_accuracy: 0.4808 - lr: 6.2500e-05
# Epoch 49/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.7473 - accuracy: 0.5493 - val_loss: 2.1499 - val_accuracy: 0.4893 - lr: 6.2500e-05
# Epoch 50/75
# 1250/1250 [==============================] - 31s 25ms/step - loss: 1.7492 - accuracy: 0.5518 - val_loss: 2.1790 - val_accuracy: 0.4816 - lr: 6.2500e-05
# Epoch 51/75
# 1250/1250 [==============================] - 27s 22ms/step - loss: 1.7445 - accuracy: 0.5520 - val_loss: 2.1670 - val_accuracy: 0.4876 - lr: 6.2500e-05
# Epoch 52/75
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.7313 - accuracy: 0.5547 - val_loss: 2.2174 - val_accuracy: 0.4758 - lr: 6.2500e-05
# Epoch 53/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7422 - accuracy: 0.5498 - val_loss: 2.1714 - val_accuracy: 0.4853 - lr: 6.2500e-05
# Epoch 54/75
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.7357 - accuracy: 0.5524 - val_loss: 2.2048 - val_accuracy: 0.4771 - lr: 6.2500e-05
# Epoch 55/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.7318 - accuracy: 0.5551 - val_loss: 2.1780 - val_accuracy: 0.4837 - lr: 3.1250e-05
# Epoch 56/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.7216 - accuracy: 0.5572 - val_loss: 2.1727 - val_accuracy: 0.4831 - lr: 3.1250e-05
# Epoch 57/75
# 1250/1250 [==============================] - 27s 21ms/step - loss: 1.7221 - accuracy: 0.5579 - val_loss: 2.1914 - val_accuracy: 0.4796 - lr: 3.1250e-05
# Epoch 58/75
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.7195 - accuracy: 0.5555 - val_loss: 2.1822 - val_accuracy: 0.4796 - lr: 3.1250e-05
# Epoch 59/75
# 1250/1250 [==============================] - 27s 21ms/step - loss: 1.7209 - accuracy: 0.5569 - val_loss: 2.1854 - val_accuracy: 0.4808 - lr: 3.1250e-05
# Epoch 60/75
# 1250/1250 [==============================] - 27s 22ms/step - loss: 1.7097 - accuracy: 0.5603 - val_loss: 2.1965 - val_accuracy: 0.4771 - lr: 1.5625e-05
# Epoch 61/75
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.7171 - accuracy: 0.5566 - val_loss: 2.1825 - val_accuracy: 0.4796 - lr: 1.5625e-05
# Epoch 62/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7159 - accuracy: 0.5589 - val_loss: 2.1792 - val_accuracy: 0.4792 - lr: 1.5625e-05
# Epoch 63/75
# 1250/1250 [==============================] - 32s 26ms/step - loss: 1.7178 - accuracy: 0.5552 - val_loss: 2.2188 - val_accuracy: 0.4719 - lr: 1.5625e-05
# Epoch 64/75
# 1250/1250 [==============================] - 23s 18ms/step - loss: 1.7100 - accuracy: 0.5577 - val_loss: 2.1746 - val_accuracy: 0.4815 - lr: 1.5625e-05
# Epoch 65/75
# 1250/1250 [==============================] - 23s 19ms/step - loss: 1.7116 - accuracy: 0.5598 - val_loss: 2.1786 - val_accuracy: 0.4793 - lr: 1.0000e-05
# Epoch 66/75
# 1250/1250 [==============================] - 26s 20ms/step - loss: 1.7125 - accuracy: 0.5571 - val_loss: 2.1818 - val_accuracy: 0.4794 - lr: 1.0000e-05
# Epoch 67/75
# 1250/1250 [==============================] - 28s 23ms/step - loss: 1.7161 - accuracy: 0.5596 - val_loss: 2.1772 - val_accuracy: 0.4798 - lr: 1.0000e-05
# Epoch 68/75
# 1250/1250 [==============================] - 32s 26ms/step - loss: 1.7067 - accuracy: 0.5616 - val_loss: 2.1854 - val_accuracy: 0.4789 - lr: 1.0000e-05
# Epoch 69/75
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.7157 - accuracy: 0.5580 - val_loss: 2.1748 - val_accuracy: 0.4814 - lr: 1.0000e-05
# Epoch 70/75
# 1250/1250 [==============================] - 28s 22ms/step - loss: 1.7055 - accuracy: 0.5591 - val_loss: 2.1763 - val_accuracy: 0.4800 - lr: 1.0000e-05
# Epoch 71/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7177 - accuracy: 0.5568 - val_loss: 2.1585 - val_accuracy: 0.4841 - lr: 1.0000e-05
# Epoch 72/75
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.7156 - accuracy: 0.5595 - val_loss: 2.1893 - val_accuracy: 0.4778 - lr: 1.0000e-05
# Epoch 73/75
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.7155 - accuracy: 0.5569 - val_loss: 2.1788 - val_accuracy: 0.4798 - lr: 1.0000e-05
# Epoch 74/75
# 1250/1250 [==============================] - 28s 22ms/step - loss: 1.7088 - accuracy: 0.5606 - val_loss: 2.1857 - val_accuracy: 0.4795 - lr: 1.0000e-05
# Epoch 75/75
# 1250/1250 [==============================] - 29s 23ms/step - loss: 1.7113 - accuracy: 0.5601 - val_loss: 2.1799 - val_accuracy: 0.4808 - lr: 1.0000e-05

# %% [markdown]
# ### Task 4b: Evaluation of the enhanced model
#
# - Re-train your model using the same number of epochs as before.
# - Compare the accuracy and other selected metric on the test set to the results you obtained before.
# - As before, plot the training accuracy and validation accuracy with respect to epochs, and select an image that the model correctly classified in the test set, and an image that the model incorrectly classified in the test set. Plot the images and report the model's classification probabilities for each.

# %%
# Your code here
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Task 4c: Discussion of the results
#
# - Briefly discuss the results.
# - Did the model's performance improve?
# - Why do you think this is?
# - Do you think there is room for further improvement? Why or why not?
# - What other techniques might you try in the future?
# - Your answer should be no more than 200 words.
#
# # Your answer here

# %% [markdown]
# The model initially achieved an accuracy of 68%, but the validation accuracy was only about 30%. Although the model seemed to perform well, it was actually overfitting: it excelled on the training data but not on the validation data. The low F1 score of 0.31 and the plot clearly indicated this, as the validation accuracy started diverging from the training accuracy after a certain point.
#
# After improving the model, the overall accuracy was 56%, but the validation accuracy significantly improved to nearly 50%. The F1 score also showed improvement. The plot illustrates that the training and validation accuracies now follow similar trends, increasing linearly.
#
# To further enhance the model, other techniques can be employed, such as trying different optimizers and loss functions, adjusting hyperparameters, or reducing the amount of training data.

# %% [markdown]
# ## Criteria
#
# |Criteria|Complete|Incomplete|
# |----|----|----|
# |Task 1|The task has been completed successfully and there are no errors.|The task is still incomplete and there is at least one error.|
# |Task 2|The task has been completed successfully and there are no errors.|The task is still incomplete and there is at least one error.|
# |Task 3|The task has been completed successfully and there are no errors.|The task is still incomplete and there is at least one error.|
# |Task 4|The task has been completed successfully and there are no errors.|The task is still incomplete and there is at least one error.|

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/deep_learning/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
